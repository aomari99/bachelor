# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("./results.csv")

# %%
# Create the default pairplot
sns.pairplot(df[["time","ent_count","sims_count"]])

# %%
df["time"].describe()
# Out:
# count    350.000000
# mean       6.117247
# std        3.884254
# min        1.990552
# 25%        3.203744
# 50%        4.706300
# 75%        7.866312
# max       19.837657
# Name: time, dtype: float64

# %%
df["time"].sum()/60
# Out:
# 35.68393884499998

# %%
(6400000/100)*5/60
# Out:
# 5333.333333333333

# %%
(6400000/5)*6/60/60/24
# Out:
# 88.8888888888889
